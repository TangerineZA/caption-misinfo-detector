# %%
import pandas as pd
import numpy as np

# %%
df_911 = pd.read_csv('./data_911.csv')
df_chemtrails = pd.read_csv('./data_chemtrails.csv')
df_flatearth = pd.read_csv('./data_flatearth.csv')
df_moonlanding = pd.read_csv('./data_moonlanding.csv')
df_vaccines = pd.read_csv('./data_vaccines.csv')

# %%
df_combined = df_chemtrails.merge(df_flatearth, 'outer')
df_combined = df_combined.merge(df_moonlanding, 'outer')
df_combined = df_combined.merge(df_vaccines, 'outer')
df_combined
# Out:
#            Topic                                        Description  \
# 0     chemtrails  Texts between Sean Hannity and convicted Trump...
# 1     chemtrails  INSTAGRAM FLYWITHCAPTAINJOE: https://goo.gl/TT...
# 2     chemtrails  Mystical BS like this drives me crazy!  Living...
# 3     chemtrails  In part three of Hello World Shenzhen, Bloombe...
# 4     chemtrails  They claim to have 10x the energy density of a...
# ...          ...                                                ...
# 1734    vaccines  US: Anti-vaccination groups blamed in Minnesot...
# 1735    vaccines  Dr. Anthony Fauci, director of the National In...
# 1736    vaccines  Parents in one Oregon town share with CNN's Ga...
# 1737    vaccines  What is the role of gov't?\nWatch Andrea Tanta...
# 1738    vaccines  “How do you respond to patient questions about...
#
#                                                   Title  \
# 0     A Judge Releases Private Texts Between Sean Ha...
# ...

# %%
df_combined.to_csv('data_combined.csv')
